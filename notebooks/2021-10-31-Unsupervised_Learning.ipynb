# %% [raw]
# ---
# aliases:
# - /jupyter/2021/10/31/Unsupervised_Learning
# badges: true
# categories:
# - jupyter
# date: '2021-10-31'
# description: A tutorial on unsupervised Learning
# image: /images/unsupervised/logo.png
# output-file: 2021-10-31-unsupervised_learning.html
# title: Unsupervised Learning
# toc: true
#
# ---

# %% [markdown]
# There are two types of unsupervised learning
#      `.1  Transformations of the Dataset`
#      `.2 Clustering`
